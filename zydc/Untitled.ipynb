# %%
run spider/zyDistrict.py

# %%
run spider/zyHuxing.py

# %%
run spider/zyYear.py

# %%
run spider/zyMianji.py

# %%
run spider/zyFollow.py

# %%
run spider/zyChaoxiang.py

# %%
run spider/zyCluster.py

# %%
clf.cluster_centers_
# Out:
# array([[  4.26658723e+03,   3.39927191e+02,   4.68085106e-02],
#        [  4.21576814e+02,   8.39378513e+01,   1.64737782e-01],
#        [  1.46023890e+03,   1.75884878e+02,   1.10966057e-01]])

# %%
house0
# Out:
#                                                house_url follow  \
# 1       http://sz.centanet.com/ershoufang/szba1116691...
# 2       http://sz.centanet.com/ershoufang/szba1116715...
# 3       http://sz.centanet.com/ershoufang/szba1116778...
# 4       http://sz.centanet.com/ershoufang/szba1116815...
# 5       http://sz.centanet.com/ershoufang/szba1116819...
# 6       http://sz.centanet.com/ershoufang/szba1117078...
# 7       http://sz.centanet.com/ershoufang/szba1117108...
# 8       http://sz.centanet.com/ershoufang/szba1117226...
# 9       http://sz.centanet.com/ershoufang/szba1117280...
# 10      http://sz.centanet.com/ershoufang/szba1117298...
# 11      http://sz.centanet.com/ershoufang/szba1117358...
# 12      http://sz.centanet.com/ershoufang/szba1117459...
# 13      http://sz.centanet.com/ershoufang/szba1117519...
# 14      http://sz.centanet.com/ershoufang/szba1118342...
# 15      http://sz.centanet.com/ershoufang/szba1118582...
# ...

# %%
run spider/zyPandas.py

# %%
huxing_group
# Out:
# huxing
# 1室       269
# 1室1厅    1451
# 1室2厅      40
# 2室         6
# 2室1厅    1329
# 2室2厅    4080
# 2室3厅       1
# 3室         5
# 3室1厅     233
# 3室2厅    6267
# 3室3厅      25
# 4室         3
# 4室1厅      25
# 4室2厅    2683
# 4室3厅      80
# 4室4厅       1
# 5室1厅       5
# 5室2厅     699
# 5室3厅     146
# 5室4厅       9
# 5室5厅       6
# 6室1厅       1
# 6室2厅     116
# 6室3厅      85
# 6室4厅      19
# 6室5厅       2
# 6室6厅       1
# 7室1厅       1
# 7室2厅      15
# 7室3厅      13
# 7室4厅       5
# 7室6厅       1
# 8室2厅       8
# 8室3厅       6
# 8室4厅       6
# 8室5厅       1
# 9室2厅       3
# 9室3厅       4
# 9室4厅       3
# 9室6厅       1
# Name: huxing, dtype: int64

# %%
clf.cluster_centers_
# Out:
# array([[  424.70113733,  2006.9777135 ],
#        [ 1481.05208333,  2007.48958333],
#        [ 4266.58723404,  2009.49361702]])

# %%
run spider/zhongyuan.py
# Out:
# [2017-04-24 19:05:31]

# %%
run spider/zyData.py
# Out:
# [2017-04-24 18:42:08]
# http://sz.centanet.com/ershoufang/szps12214236.html
# 带看28次
# 150万|2室2厅|67.29平
# 南|2014年|中层(共32层)|豪装|中粮一品澜山花园|
# {'follow': u'\u5e26\u770b28\u6b21', 'price_area': u'150\u4e07|2\u5ba42\u5385|67.29\u5e73', 'houseinfo': u'\u5357|2014\u5e74|\u4e2d\u5c42(\u517132\u5c42)|\u8c6a\u88c5|\u4e2d\u7cae\u4e00\u54c1\u6f9c\u5c71\u82b1\u56ed|', 'house_url': u'http://sz.centanet.com/ershoufang/szps12214236.html'}
# [2017-04-24 18:42:13]
# 4.32863497734s

# %%
run spider/zyData.py
# Out:
# [2017-04-25 21:43:29]
# 33
# 364
# 500
# [2017-04-25 21:45:41]
# 132.05155015s

# %%
run spider/zyData.py
# Out:
# [2017-04-25 21:46:05]
# 33
# 364
# 500
# [2017-04-25 21:48:02]
# 116.710713148s

# %%
run spider/zyData.py
# Out:
# [2017-04-25 21:48:33]
# 33
# 364
# 500
# [2017-04-25 21:49:45]
# 72.4460811615s

# %%
run spider/zyData.py
# Out:
# [2017-04-25 21:50:25]
# 33
# 364
# 500
# [2017-04-25 21:51:28]
# 62.785422802s

# %%
run spider/zyData.py
# Out:
# [2017-04-25 22:06:33]
# 33
# 364
# 500
# [2017-04-25 22:07:25]
# 51.2619841099s

# %%
run spider/zyData.py
# Out:
# [2017-04-25 22:07:43]
# 33
# 364
# 1000
# [2017-04-25 22:10:20]
# 156.521114111s

# %%
run spider/zyData.py
# Out:
# [2017-04-26 23:57:14]
# 1
# 1000
# 2
# 2000
# 3
# 3000
# 4
# 4000
# 5
# 5000
# 6
# 6000
# 7
# 7000
# 8
# 8000
# 9
# 9000
# 10
# 10000
# 11
# 11000
# 12
# 12000
# 13
# 13000
# 14
# 14000
# 15
# 15000
# [2017-04-27 00:39:36]
# 2542.34853005s

# %%
run spider/zyData.py
# Out:
# [2017-04-27 00:43:42]
# [2017-04-27 00:44:49]
# 66.2025699615s
